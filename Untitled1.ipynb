# %%
import numpy as np
import pandas as pd
import datetime
import time

# Function to generate synthetic sensor data
def generate_sensor_data(temperature_threshold=80, vibration_threshold=0.6):
    # Generate timestamps for the data
    timestamp = datetime.datetime.now()

    # Generate synthetic sensor data
    vibration_data = np.random.normal(0.5, 0.1)
    moisture_data = np.random.normal(40, 5)
    temperature_data = np.random.normal(70, 5)

    # Add failure labels and error types based on conditions
    failure_label = 0 if temperature_data <= temperature_threshold and vibration_data <= vibration_threshold else 1
    error_type = 'None' if failure_label == 0 else ('High Temperature' if temperature_data > temperature_threshold else 'High Vibration')

    # Create a DataFrame to store the sensor data with failure labels and error types
    sensor_data = pd.DataFrame({
        'Timestamp': [timestamp],
        'Vibration': [vibration_data],
        'Moisture': [moisture_data],
        'Temperature': [temperature_data],
        'FailureLabel': [failure_label],
        'ErrorType': [error_type]
    })

    return sensor_data

# Define failure thresholds
temperature_threshold = 80
vibration_threshold = 0.6

# Continuous generation of sensor data
while True:
    # Generate real-time sensor data
    real_time_sensor_data = generate_sensor_data(temperature_threshold, vibration_threshold)

    # Append the data to an existing CSV file or perform other operations as needed
    with open('real_time.csv', 'a') as f:
        real_time_sensor_data.to_csv(f, header=f.tell()==0, index=False)  # Append without header if file already exists

    # Display the generated sensor data
    print(real_time_sensor_data)

    # Wait for a specified interval (e.g., 1 second) before generating the next data
    time.sleep(5)
# Out:
#                    Timestamp  Vibration   Moisture  Temperature  FailureLabel  \
# 0 2024-03-29 18:19:34.742439   0.432439  32.825051    69.049424             0
#
#   ErrorType
# 0      None
#                    Timestamp  Vibration   Moisture  Temperature  FailureLabel  \
# 0 2024-03-29 18:19:39.831903   0.436788  35.860055    65.853087             0
#
#   ErrorType
# 0      None
#                    Timestamp  Vibration   Moisture  Temperature  FailureLabel  \
# 0 2024-03-29 18:19:44.857278   0.529232  38.458119    78.349322             0
#
#   ErrorType
# 0      None
#                    Timestamp  Vibration   Moisture  Temperature  FailureLabel  \
# 0 2024-03-29 18:19:49.884312   0.511159  40.590357    63.958942             0
#
#   ErrorType
# 0      None
#                    Timestamp  Vibration   Moisture  Temperature  FailureLabel  \
# 0 2024-03-29 18:19:54.904964   0.469614  44.624658    64.407506             0
#
#   ErrorType
# 0      None
#                    Timestamp  Vibration   Moisture  Temperature  FailureLabel  \
# 0 2024-03-29 18:19:59.919064   0.602833  42.606446    73.626389             1
#
#         ErrorType
# 0  High Vibration
#                    Timestamp  Vibration   Moisture  Temperature  FailureLabel  \
# 0 2024-03-29 18:20:04.938269   0.395032  46.414578     70.04969             0
#
#   ErrorType
# 0      None
#                    Timestamp  Vibration   Moisture  Temperature  FailureLabel  \
# 0 2024-03-29 18:20:09.955422   0.547235  41.847797    70.244978             0
#
#   ErrorType
# 0      None
#                    Timestamp  Vibration   Moisture  Temperature  FailureLabel  \
# 0 2024-03-29 18:20:14.969949   0.436162  44.987233    71.876796             0
#
#   ErrorType
# 0      None
#                    Timestamp  Vibration   Moisture  Temperature  FailureLabel  \
# 0 2024-03-29 18:20:19.986798   0.502271  31.508279    65.756583             0
#
#   ErrorType
# 0      None
#                    Timestamp  Vibration   Moisture  Temperature  FailureLabel  \
# 0 2024-03-29 18:20:25.003453   0.518091  35.250712    72.581705             0
#
#   ErrorType
# 0      None
#                    Timestamp  Vibration   Moisture  Temperature  FailureLabel  \
# 0 2024-03-29 18:20:30.028983   0.610302  30.419701    66.031192             1
#
#         ErrorType
# 0  High Vibration
#                    Timestamp  Vibration   Moisture  Temperature  FailureLabel  \
# 0 2024-03-29 18:20:35.034410   0.494532  36.598484    72.009985             0
#
#   ErrorType
# 0      None
#                    Timestamp  Vibration   Moisture  Temperature  FailureLabel  \
# 0 2024-03-29 18:20:40.040812   0.503883  36.583801    55.984934             0
#
#   ErrorType
# 0      None
#                    Timestamp  Vibration   Moisture  Temperature  FailureLabel  \
# 0 2024-03-29 18:20:45.047391   0.538136  45.784023     72.52076             0
#
#   ErrorType
# 0      None
#                    Timestamp  Vibration   Moisture  Temperature  FailureLabel  \
# 0 2024-03-29 18:20:50.059013   0.446024  35.119629    73.362172             0
#
#   ErrorType
# 0      None
#                    Timestamp  Vibration   Moisture  Temperature  FailureLabel  \
# 0 2024-03-29 18:20:55.082180   0.504982  36.921326    64.507458             0
#
#   ErrorType
# 0      None
#                    Timestamp  Vibration   Moisture  Temperature  FailureLabel  \
# 0 2024-03-29 18:21:00.102071   0.604822  37.590007    63.985154             1
#
#         ErrorType
# 0  High Vibration
#                    Timestamp  Vibration   Moisture  Temperature  FailureLabel  \
# 0 2024-03-29 18:21:05.114233   0.537366  44.359121     78.61602             0
#
#   ErrorType
# 0      None
#                    Timestamp  Vibration   Moisture  Temperature  FailureLabel  \
# 0 2024-03-29 18:21:10.126353   0.406716  44.499287    76.597783             0
#
#   ErrorType
# 0      None
#                    Timestamp  Vibration   Moisture  Temperature  FailureLabel  \
# 0 2024-03-29 18:21:15.150873    0.49594  37.566304    71.970623             0
#
#   ErrorType
# 0      None
#                    Timestamp  Vibration   Moisture  Temperature  FailureLabel  \
# 0 2024-03-29 18:21:20.156231   0.383463  42.513654    74.438396             0
#
#   ErrorType
# 0      None
#                    Timestamp  Vibration   Moisture  Temperature  FailureLabel  \
# 0 2024-03-29 18:21:25.166904   0.426304  37.708589    65.259873             0
#
#   ErrorType
# 0      None
#                    Timestamp  Vibration   Moisture  Temperature  FailureLabel  \
# 0 2024-03-29 18:21:30.173515   0.597637  35.417042    67.983568             0
#
#   ErrorType
# 0      None
#                    Timestamp  Vibration   Moisture  Temperature  FailureLabel  \
# 0 2024-03-29 18:21:35.180408   0.696457  37.540112    67.481731             1
#
#         ErrorType
# 0  High Vibration
#                    Timestamp  Vibration   Moisture  Temperature  FailureLabel  \
# 0 2024-03-29 18:21:40.188735   0.505974  57.966807    74.322484             0
#
#   ErrorType
# 0      None
#                    Timestamp  Vibration   Moisture  Temperature  FailureLabel  \
# 0 2024-03-29 18:21:45.209106   0.539561  37.412253    56.978785             0
#
#   ErrorType
# 0      None
#                    Timestamp  Vibration   Moisture  Temperature  FailureLabel  \
# 0 2024-03-29 18:21:50.236207   0.375386  40.795751    73.831575             0
#
#   ErrorType
# 0      None
#                    Timestamp  Vibration   Moisture  Temperature  FailureLabel  \
# 0 2024-03-29 18:21:55.246028   0.471603  34.664156     71.87127             0
#
#   ErrorType
# 0      None
#                    Timestamp  Vibration   Moisture  Temperature  FailureLabel  \
# 0 2024-03-29 18:22:00.268292   0.471161  35.433672    65.963501             0
#
#   ErrorType
# 0      None
#                    Timestamp  Vibration   Moisture  Temperature  FailureLabel  \
# 0 2024-03-29 18:22:05.283329   0.546893  45.238926     65.11541             0
#
#   ErrorType
# 0      None
#                    Timestamp  Vibration   Moisture  Temperature  FailureLabel  \
# 0 2024-03-29 18:22:10.289306   0.504716  33.735334    62.300562             0
#
#   ErrorType
# 0      None
#                    Timestamp  Vibration   Moisture  Temperature  FailureLabel  \
# 0 2024-03-29 18:22:15.326162   0.413936  37.094648    67.331909             0
#
#   ErrorType
# 0      None
#                    Timestamp  Vibration   Moisture  Temperature  FailureLabel  \
# 0 2024-03-29 18:22:20.349431   0.446636  44.620993    63.808415             0
#
#   ErrorType
# 0      None
#                    Timestamp  Vibration   Moisture  Temperature  FailureLabel  \
# 0 2024-03-29 18:22:25.372071   0.304019  44.170484    62.781772             0
#
#   ErrorType
# 0      None
#                    Timestamp  Vibration   Moisture  Temperature  FailureLabel  \
# 0 2024-03-29 18:22:30.393690   0.610466  46.029022    65.743516             1
#
#         ErrorType
# 0  High Vibration
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 49
#      46 print(real_time_sensor_data)
#      48 # Wait for a specified interval (e.g., 1 second) before generating the next data
# ---> 49 time.sleep(5)
#
# KeyboardInterrupt:
